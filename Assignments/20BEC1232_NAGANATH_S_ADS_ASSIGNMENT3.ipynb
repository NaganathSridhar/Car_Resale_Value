# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Housing.csv')

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
#3) (1) UNIVARIATE ANALYSIS

plt.pie(data.mainroad.value_counts(),colors=['orange','yellow'], labels=['Yes','No'],autopct='%.2f%%')
plt.title('Main road')
# Out:
# Text(0.5, 1.0, 'Main road')

# %%
sns.displot(data.bedrooms)
plt.title('Bedrooms')
# Out:
# Text(0.5, 1.0, 'Bedrooms')

# %%
plt.hist(data.basement,color='g')
plt.title('Basement')
# Out:
# Text(0.5, 1.0, 'Basement')

# %%
plt.pie(data.parking.value_counts(),colors=['cyan','green','orange','yellow'], labels=['0','1','2','3'],autopct='%.2f%%')
plt.title('Parking')
# Out:
# Text(0.5, 1.0, 'Parking')

# %%
#3) (2) Bivariate analysis

plt.plot(data.stories,data.area,color='c')
plt.xlabel('Stories')
plt.ylabel('Area')
plt.title('Stories vs Area')
# Out:
# Text(0.5, 1.0, 'Stories vs Area')

# %%
plt.scatter(data.furnishingstatus,data.bathrooms,color='k')
plt.xlabel('Furnishing status')
plt.ylabel('Bath rooms')
plt.title('Furnishing status vs Bath rooms')
# Out:
# Text(0.5, 1.0, 'Furnishing status vs Bath rooms')

# %%
plt.bar(data.parking,data.area)
# Out:
# <BarContainer object of 545 artists>

# %%
#3) (3) Multivariate analysis

pd.plotting.scatter_matrix(data.loc[:,'bedrooms':'parking'],diagonal='kde',figsize=(20,15),color='g')
# Out:
# array([[<Axes: xlabel='bedrooms', ylabel='bedrooms'>,
#         <Axes: xlabel='bathrooms', ylabel='bedrooms'>,
#         <Axes: xlabel='stories', ylabel='bedrooms'>,
#         <Axes: xlabel='parking', ylabel='bedrooms'>],
#        [<Axes: xlabel='bedrooms', ylabel='bathrooms'>,
#         <Axes: xlabel='bathrooms', ylabel='bathrooms'>,
#         <Axes: xlabel='stories', ylabel='bathrooms'>,
#         <Axes: xlabel='parking', ylabel='bathrooms'>],
#        [<Axes: xlabel='bedrooms', ylabel='stories'>,
#         <Axes: xlabel='bathrooms', ylabel='stories'>,
#         <Axes: xlabel='stories', ylabel='stories'>,
#         <Axes: xlabel='parking', ylabel='stories'>],
#        [<Axes: xlabel='bedrooms', ylabel='parking'>,
#         <Axes: xlabel='bathrooms', ylabel='parking'>,
#         <Axes: xlabel='stories', ylabel='parking'>,
#         <Axes: xlabel='parking', ylabel='parking'>]], dtype=object)

# %%
ax = data[["area","bathrooms"]].plot(figsize=(20,15))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
#4) Descriptive statistics

data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
data.var() #Variance of data
# Out:
# <ipython-input-464-9451cbd3245a>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var() #Variance of data
# price        3.498544e+12
# area         4.709512e+06
# bedrooms     5.447383e-01
# bathrooms    2.524757e-01
# stories      7.525432e-01
# parking      7.423300e-01
# dtype: float64

# %%
data.mode() #Mode of data
# Out:
#      price    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  3500000  6000.0       3.0        1.0      2.0      yes        no       no
# 1  4200000     NaN       NaN        NaN      NaN      NaN       NaN      NaN
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no              no      0.0   semi-furnished
# 1             NaN             NaN      NaN              NaN

# %%
data.median() #Median of data
# Out:
# <ipython-input-466-8af4487b14c3>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median() #Median of data
# price        4340000.0
# area            4600.0
# bedrooms           3.0
# bathrooms          1.0
# stories            2.0
# parking            0.0
# dtype: float64

# %%
#5) Handling missing values

data.isnull().any()
# Out:
# price               False
# area                False
# bedrooms            False
# bathrooms           False
# stories             False
# mainroad            False
# guestroom           False
# basement            False
# hotwaterheating     False
# airconditioning     False
# parking             False
# furnishingstatus    False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %%
#6) Outliers management

data_new = pd.read_csv("Housing.csv")
sns.boxplot(data_new.area)
# Out:
# <Axes: >

# %%
perc99=data.area.quantile(0.95)
perc99
# Out:
# 9000.0

# %%
data_new = pd.read_csv("Housing.csv")
data_new=data_new[data_new.area<=perc99]
sns.boxplot(data_new.area)
# Out:
# <Axes: >

# %%
#LABEL ENCODING

from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data.guestroom=le.fit_transform(data.guestroom)

# %%
data.hotwaterheating=le.fit_transform(data.hotwaterheating)

# %%
data.mainroad=le.fit_transform(data.mainroad)

# %%
data.basement=le.fit_transform(data.basement)

# %%
data.airconditioning=le.fit_transform(data.airconditioning)

# %%
data.furnishingstatus=le.fit_transform(data.furnishingstatus)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  furnishingstatus
# 0         0                0                1        2                 0
# 1         0                0                1        3                 0
# 2         1                0                0        2                 1
# 3         1                0                1        3                 0
# 4         1                0                1        2                 0

# %%
#8) Split the dataset into dependent and independent variable

y=data['price']

# %%
y.head()
# Out:
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# Name: price, dtype: int64

# %%
X=data.drop(columns=['price'],axis=1)

# %%
X.head()
# Out:
#    area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0  7420         4          2        3         1          0         0
# 1  8960         4          4        4         1          0         0
# 2  9960         3          2        2         1          0         1
# 3  7500         4          2        2         1          0         1
# 4  7420         4          1        2         1          1         1
#
#    hotwaterheating  airconditioning  parking  furnishingstatus
# 0                0                1        2                 0
# 1                0                1        3                 0
# 2                0                0        2                 1
# 3                0                1        3                 0
# 4                0                1        2                 0

# %%
#9) Scaling the independent variables

name=X.columns
name
# Out:
# Index(['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom',
#        'basement', 'hotwaterheating', 'airconditioning', 'parking',
#        'furnishingstatus'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale=MinMaxScaler()

# %%
X_scaled=scale.fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.39656357, 0.6       , 0.33333333, ..., 1.        , 0.66666667,
#         0.        ],
#        [0.5024055 , 0.6       , 1.        , ..., 1.        , 1.        ,
#         0.        ],
#        [0.57113402, 0.4       , 0.33333333, ..., 0.        , 0.66666667,
#         0.5       ],
#        ...,
#        [0.13539519, 0.2       , 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.08659794, 0.4       , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.15120275, 0.4       , 0.        , ..., 0.        , 0.        ,
#         1.        ]])

# %%
X=pd.DataFrame(X_scaled,columns=name)

# %%
X
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 0    0.396564       0.6   0.333333  0.666667       1.0        0.0       0.0
# 1    0.502405       0.6   1.000000  1.000000       1.0        0.0       0.0
# 2    0.571134       0.4   0.333333  0.333333       1.0        0.0       1.0
# 3    0.402062       0.6   0.333333  0.333333       1.0        0.0       1.0
# 4    0.396564       0.6   0.000000  0.333333       1.0        1.0       1.0
# ..        ...       ...        ...       ...       ...        ...       ...
# 540  0.092784       0.2   0.000000  0.000000       1.0        0.0       1.0
# 541  0.051546       0.4   0.000000  0.000000       0.0        0.0       0.0
# 542  0.135395       0.2   0.000000  0.000000       1.0        0.0       0.0
# 543  0.086598       0.4   0.000000  0.000000       0.0        0.0       0.0
# 544  0.151203       0.4   0.000000  0.333333       1.0        0.0       0.0
#
# ...

# %%
#10) Train test split

from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.02,random_state=0)

# %%
X_train.head()
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 329  0.158763       0.4        0.0  0.333333       1.0        0.0       0.0
# 450  0.123711       0.4        0.0  0.333333       1.0        0.0       1.0
# 432  0.303093       0.4        0.0  0.000000       1.0        1.0       1.0
# 310  0.297938       0.4        0.0  0.000000       1.0        0.0       1.0
# 501  0.053608       0.4        0.0  0.000000       0.0        0.0       0.0
#
#      hotwaterheating  airconditioning  parking  furnishingstatus
# 329              0.0              0.0      0.0               0.0
# 450              0.0              0.0      0.0               0.5
# 432              0.0              0.0      0.0               0.0
# 310              0.0              0.0      0.0               0.5
# 501              0.0              0.0      0.0               1.0

# %%
X_test.head()
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 239  0.161512       0.4        0.0  0.333333       1.0        0.0       0.0
# 113  0.547766       0.4        0.0  0.000000       1.0        0.0       1.0
# 325  0.124399       0.6        0.0  0.333333       1.0        0.0       0.0
# 66   0.793814       0.2        0.0  0.000000       1.0        0.0       1.0
# 479  0.138144       0.6        0.0  0.333333       0.0        0.0       0.0
#
#      hotwaterheating  airconditioning   parking  furnishingstatus
# 239              0.0              0.0  0.333333               0.0
# 113              0.0              0.0  0.666667               0.0
# 325              0.0              1.0  0.000000               0.5
# 66               1.0              0.0  0.333333               0.0
# 479              0.0              0.0  0.000000               1.0

# %%
y_train
# Out:
# 329    3990000
# 450    3150000
# 432    3290000
# 310    4130000
# 501    2660000
#         ...
# 70     6790000
# 277    4305000
# 9      9800000
# 359    3710000
# 192    5040000
# Name: price, Length: 534, dtype: int64

# %%
y_test
# Out:
# 239    4585000
# 113    6083000
# 325    4007500
# 66     6930000
# 479    2940000
# 103    6195000
# 386    3535000
# 480    2940000
# 400    3500000
# 37     7980000
# 71     6755000
# Name: price, dtype: int64

# %%
#11) Building the model

from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
#12) Training the model

model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#13) Testing the model

pred=model.predict(X_test)

# %%
y_test
# Out:
# 239    4585000
# 113    6083000
# 325    4007500
# 66     6930000
# 479    2940000
# 103    6195000
# 386    3535000
# 480    2940000
# 400    3500000
# 37     7980000
# 71     6755000
# Name: price, dtype: int64

# %%
#14) Performance metrics

E=pred-y_test
E
# Out:
# 239   -449348.790127
# 113   -167608.394484
# 325    496224.841324
# 66     368201.611780
# 479    -10173.436484
# 103    963178.128369
# 386    -92124.755387
# 480    311470.918548
# 400   -545097.791576
# 37     688766.325612
# 71     113937.438029
# Name: price, dtype: float64

# %%
from sklearn.metrics import r2_score

# %%
r2_score(pred,y_test)*100
# Out:
# 94.25098215638074

# %%
from sklearn.metrics import mean_squared_error,r2_score, mean_absolute_error

# %%
se=E*E

# %%
se
# Out:
# 239    2.019143e+11
# 113    2.809257e+10
# 325    2.462391e+11
# 66     1.355724e+11
# 479    1.034988e+08
# 103    9.277121e+11
# 386    8.486971e+09
# 480    9.701413e+10
# 400    2.971316e+11
# 37     4.743991e+11
# 71     1.298174e+10
# Name: price, dtype: float64

# %%
mse=np.mean(se)
mse
# Out:
# 220877048368.27676

# %%
mse2=mean_squared_error(y_test,pred)
mse
# Out:
# 220877048368.27676

# %%
mae=mean_absolute_error(y_test,pred)
mae
# Out:
# 382375.6756108617

# %%
rmse=np.sqrt(mse2)
rmse
# Out:
# 469975.5827362489
